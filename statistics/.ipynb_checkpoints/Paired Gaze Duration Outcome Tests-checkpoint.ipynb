# %% [markdown]
# # Imports

# %%
# %matplotlib inline

import scipy as sp
from scipy import stats
import numpy as np
import pandas as pd

import statistics

# %% [markdown]
# # Load Data

# %%
tracing_df = statistics.load_tracing_features()
recording_df = statistics.load_recording_relations()
recording_df = statistics.associate_recordings(recording_df, tracing_df)
gaze_dfs = statistics.load_gaze_features()
statistics.check_gaze_recording_associations(recording_df, gaze_dfs)
statistics.compute_gaze_features(gaze_dfs)
gaze_df = statistics.combine_gaze_features(gaze_dfs)
full_df = statistics.combine_all_features(recording_df, gaze_df)
full_df.columns
# Out:
# Index(['id', 'subjectNumber', 'scenarioNumber', 'newAfterOld', 'scenarioType',
#        'displayType', 'sensorPlacementTime', 'ppvStartTime', 'ccStartTime',
#        'inSpO2TargetRangeDuration', 'inSpO2LooseTargetRangeDuration',
#        'inSpO2TargetRangeStartTime', 'aboveSpO2TargetRangeDuration',
#        'belowSpO2TargetRangeDuration', 'inFiO2TargetRangeDuration',
#        'inFiO2TargetRangeStartTime', 'aboveFiO2TargetRangeDuration',
#        'belowFiO2TargetRangeDuration', 'spO2SignedErrorIntegral',
#        'spO2UnsignedErrorIntegral', 'spO2SquaredErrorIntegral',
#        'fiO2LargeAdjustments', 'code', 'visitDuration_fiO2Dial',
#        'visitDuration_infant', 'visitDuration_monitorApgarTimer',
#        'visitDuration_monitorBlank', 'visitDuration_monitorFiO2',
#        'visitDuration_monitorFull', 'visitDuration_monitorGraph',
#        'visitDuration_monitorHeartRate', 'visitDuration_monitorSpO2',
#        'visitDuration_spO2ReferenceTable',
#        'visitDuration_warmerInstrumentPanel', 'visitDuration_combinedFiO2',
#        'visitDuration_combinedSpO2', 'visitCount_fiO2Dial',
#        'visitCount_infant', 'visitCount_monitorApgarTimer',
#        'visitCount_monitorBlank', 'visitCount_monitorFiO2',
#        'visitCount_monitorFull', 'visitCount_monitorGraph',
#        'visitCount_monitorHeartRate', 'visitCount_monitorSpO2',
#        'visitCount_spO2ReferenceTable', 'visitCount_warmerInstrumentPanel',
#        'visitCount_combinedFiO2', 'visitCount_combinedSpO2'],
#       dtype='object')

# %% [markdown]
# # Pairing

# %% [markdown]
# ### Scenario Type Pairing

# %%
scenario_pairing = statistics.build_pairing(full_df, 'scenarioType')

# %%
scenario_pairing.describe()
# Out:
# Pairing against scenarioType:
#   0: easy vs. 1: hard
#   28 0 vs. 1 pairs.
#   Paired t-test alternative hypotheses:
#     Ha left-tailed (diff < 0): mean 0 - mean 1 < 0
#     Ha two-tailed (|diff| > 0): mean 0 - mean 1 != 0
#     Ha right-tailed (diff > 0): mean 0 - mean 1 > 0

# %%
statistics.test_gaze_duration_outcomes(scenario_pairing)
# Out:
# visitDuration_infant:
#   mean diff = -10.389; stdev diff = 26.111
#   Paired t-test:
#   **|diff| > 0: p = 0.048
#   **diff < 0: p = 0.024
#     diff > 0: p = 0.976
# visitDuration_warmerInstrumentPanel:
#   mean diff = 0.918; stdev diff = 7.820
#   Paired t-test:
#     |diff| > 0: p = 0.547
#     diff < 0: p = 0.726
#     diff > 0: p = 0.274
# visitDuration_fiO2Dial:
#   mean diff = 2.456; stdev diff = 5.147
#   Paired t-test:
#   **|diff| > 0: p = 0.020
#     diff < 0: p = 0.990
#   **diff > 0: p = 0.010
# visitDuration_spO2ReferenceTable:
#   mean diff = 3.498; stdev diff = 6.026
#   Paired t-test:
#   **|diff| > 0: p = 0.006
#     diff < 0: p = 0.997
#   **diff > 0: p = 0.003
# visitDuration_monitorFull:
#   mean diff = -5.040; stdev diff = 29.838
#   Paired t-test:
#     |diff| > 0: p = 0.388
#    ~diff < 0: p = 0.194
#     diff > 0: p = 0.806
# visitDuration_monitorBlank:
#   mean diff = -1.204; stdev diff = 7.774
#   Paired t-test:
#     |diff| > 0: p = 0.428
#     diff < 0: p = 0.214
#     diff > 0: p = 0.786
# visitDuration_monitorApgarTimer:
#   mean diff = -1.995; stdev diff = 8.712
#   Paired t-test:
#     |diff| > 0: p = 0.244
#    ~diff < 0: p = 0.122
#     diff > 0: p = 0.878
# visitDuration_monitorHeartRate:
#   mean diff = -10.042; stdev diff = 17.044
#   Paired t-test:
#   **|diff| > 0: p = 0.005
#   **diff < 0: p = 0.002
#     diff > 0: p = 0.998
# visitDuration_monitorSpO2:
#   mean diff = 4.727; stdev diff = 17.657
#   Paired t-test:
#    ~|diff| > 0: p = 0.176
#     diff < 0: p = 0.912
#    *diff > 0: p = 0.088
# visitDuration_combinedFiO2:
#   mean diff = 0.279; stdev diff = 8.348
#   Paired t-test:
#     |diff| > 0: p = 0.863
#     diff < 0: p = 0.568
#     diff > 0: p = 0.432
# visitDuration_combinedSpO2:
#   mean diff = 12.538; stdev diff = 24.530
#   Paired t-test:
#   **|diff| > 0: p = 0.013
#     diff < 0: p = 0.993
#   **diff > 0: p = 0.007

# %% [markdown]
# Observations:
#
# * Subjects look at the infant less, the FiO2 dial more, the SpO2 reference table more, the heart rate less, the SpO2 number maybe more, and the combined SpO2 elements more in the easy scenario than in the hard scenario.

# %% [markdown]
# ### Display Type Pairing

# %%
display_pairing = statistics.build_pairing(full_df, 'displayType')

# %%
display_pairing.describe()
# Out:
# Pairing against displayType:
#   0: minimal vs. 1: full
#   32 0 vs. 1 pairs.
#   Paired t-test alternative hypotheses:
#     Ha left-tailed (diff < 0): mean 0 - mean 1 < 0
#     Ha two-tailed (|diff| > 0): mean 0 - mean 1 != 0
#     Ha right-tailed (diff > 0): mean 0 - mean 1 > 0

# %%
statistics.test_gaze_duration_outcomes(display_pairing)
# Out:
# visitDuration_infant:
#   mean diff = 0.941; stdev diff = 22.803
#   Paired t-test:
#     |diff| > 0: p = 0.820
#     diff < 0: p = 0.590
#     diff > 0: p = 0.410
# visitDuration_warmerInstrumentPanel:
#   mean diff = -0.812; stdev diff = 8.616
#   Paired t-test:
#     |diff| > 0: p = 0.603
#     diff < 0: p = 0.302
#     diff > 0: p = 0.698
# visitDuration_fiO2Dial:
#   mean diff = 0.952; stdev diff = 4.954
#   Paired t-test:
#     |diff| > 0: p = 0.293
#     diff < 0: p = 0.854
#    ~diff > 0: p = 0.146
# visitDuration_spO2ReferenceTable:
#   mean diff = 0.444; stdev diff = 4.554
#   Paired t-test:
#     |diff| > 0: p = 0.591
#     diff < 0: p = 0.704
#     diff > 0: p = 0.296
# visitDuration_monitorFull:
#   mean diff = -7.363; stdev diff = 27.431
#   Paired t-test:
#    ~|diff| > 0: p = 0.145
#    *diff < 0: p = 0.073
#     diff > 0: p = 0.927
# visitDuration_monitorBlank:
#   mean diff = 3.414; stdev diff = 9.080
#   Paired t-test:
#   **|diff| > 0: p = 0.045
#     diff < 0: p = 0.978
#   **diff > 0: p = 0.022
# visitDuration_monitorApgarTimer:
#   mean diff = 4.466; stdev diff = 10.002
#   Paired t-test:
#   **|diff| > 0: p = 0.018
#     diff < 0: p = 0.991
#   **diff > 0: p = 0.009
# visitDuration_monitorHeartRate:
#   mean diff = 6.543; stdev diff = 14.886
#   Paired t-test:
#   **|diff| > 0: p = 0.020
#     diff < 0: p = 0.990
#   **diff > 0: p = 0.010
# visitDuration_monitorSpO2:
#   mean diff = 9.879; stdev diff = 20.654
#   Paired t-test:
#   **|diff| > 0: p = 0.012
#     diff < 0: p = 0.994
#   **diff > 0: p = 0.006
# visitDuration_combinedFiO2:
#   mean diff = -9.142; stdev diff = 8.748
#   Paired t-test:
#   **|diff| > 0: p = 0.000
#   **diff < 0: p = 0.000
#     diff > 0: p = 1.000
# visitDuration_combinedSpO2:
#   mean diff = -10.880; stdev diff = 21.089
#   Paired t-test:
#   **|diff| > 0: p = 0.007
#   **diff < 0: p = 0.004
#     diff > 0: p = 0.996

# %% [markdown]
# Observations:
#
# * Subjects look at the monitor maybe more, the blank parts of the monitor less, the apgar timer less, the heart rate less, the SpO2 number less, the combined FiO2 elements more, and the combined SpO2 elements more in the full display than in the minimal display.

# %% [markdown]
# ### Display Type Pairing, Split by Scenario

# %%
scenario_display_pairings = {
    scenario: statistics.build_pairing(scenario_subset, 'displayType')
    for (scenario, scenario_subset) in enumerate(scenario_pairing)
}

# %% [markdown]
# #### Easy Scenarios

# %%
scenario_display_pairings[0].describe()
# Out:
# Pairing against displayType:
#   0: minimal vs. 1: full
#   14 0 vs. 1 pairs.
#   Paired t-test alternative hypotheses:
#     Ha left-tailed (diff < 0): mean 0 - mean 1 < 0
#     Ha two-tailed (|diff| > 0): mean 0 - mean 1 != 0
#     Ha right-tailed (diff > 0): mean 0 - mean 1 > 0

# %%
statistics.test_gaze_duration_outcomes(scenario_display_pairings[0])
# Out:
# visitDuration_infant:
#   mean diff = -2.972; stdev diff = 17.800
#   Paired t-test:
#     |diff| > 0: p = 0.558
#     diff < 0: p = 0.279
#     diff > 0: p = 0.721
# visitDuration_warmerInstrumentPanel:
#   mean diff = -0.059; stdev diff = 8.077
#   Paired t-test:
#     |diff| > 0: p = 0.980
#     diff < 0: p = 0.490
#     diff > 0: p = 0.510
# visitDuration_fiO2Dial:
#   mean diff = 0.570; stdev diff = 5.201
#   Paired t-test:
#     |diff| > 0: p = 0.699
#     diff < 0: p = 0.650
#     diff > 0: p = 0.350
# visitDuration_spO2ReferenceTable:
#   mean diff = -0.431; stdev diff = 5.641
#   Paired t-test:
#     |diff| > 0: p = 0.787
#     diff < 0: p = 0.394
#     diff > 0: p = 0.606
# visitDuration_monitorFull:
#   mean diff = -5.233; stdev diff = 33.700
#   Paired t-test:
#     |diff| > 0: p = 0.585
#     diff < 0: p = 0.293
#     diff > 0: p = 0.707
# visitDuration_monitorBlank:
#   mean diff = 2.861; stdev diff = 6.356
#   Paired t-test:
#    ~|diff| > 0: p = 0.129
#     diff < 0: p = 0.936
#    *diff > 0: p = 0.064
# visitDuration_monitorApgarTimer:
#   mean diff = 2.672; stdev diff = 9.071
#   Paired t-test:
#     |diff| > 0: p = 0.307
#     diff < 0: p = 0.846
#    ~diff > 0: p = 0.154
# visitDuration_monitorHeartRate:
#   mean diff = 8.124; stdev diff = 16.776
#   Paired t-test:
#    ~|diff| > 0: p = 0.104
#     diff < 0: p = 0.948
#    *diff > 0: p = 0.052
# visitDuration_monitorSpO2:
#   mean diff = 11.300; stdev diff = 25.805
#   Paired t-test:
#    ~|diff| > 0: p = 0.138
#     diff < 0: p = 0.931
#    *diff > 0: p = 0.069
# visitDuration_combinedFiO2:
#   mean diff = -7.307; stdev diff = 5.449
#   Paired t-test:
#   **|diff| > 0: p = 0.000
#   **diff < 0: p = 0.000
#     diff > 0: p = 1.000
# visitDuration_combinedSpO2:
#   mean diff = -12.304; stdev diff = 24.872
#   Paired t-test:
#    *|diff| > 0: p = 0.098
#   **diff < 0: p = 0.049
#     diff > 0: p = 0.951

# %% [markdown]
# Observations:
#
# * Subjects look at the blank parts of the monitor maybe less, the heart rate maybe less, the SpO2 number maybe less, the combined FiO2 elements more, and the combined SpO2 elements more in the full display than in the minimal display.

# %% [markdown]
# #### Hard Scenarios

# %%
scenario_display_pairings[1].describe()
# Out:
# Pairing against displayType:
#   0: minimal vs. 1: full
#   14 0 vs. 1 pairs.
#   Paired t-test alternative hypotheses:
#     Ha left-tailed (diff < 0): mean 0 - mean 1 < 0
#     Ha two-tailed (|diff| > 0): mean 0 - mean 1 != 0
#     Ha right-tailed (diff > 0): mean 0 - mean 1 > 0

# %%
statistics.test_gaze_duration_outcomes(scenario_display_pairings[1])
# Out:
# visitDuration_infant:
#   mean diff = 1.495; stdev diff = 23.894
#   Paired t-test:
#     |diff| > 0: p = 0.825
#     diff < 0: p = 0.588
#     diff > 0: p = 0.412
# visitDuration_warmerInstrumentPanel:
#   mean diff = -0.731; stdev diff = 9.523
#   Paired t-test:
#     |diff| > 0: p = 0.786
#     diff < 0: p = 0.393
#     diff > 0: p = 0.607
# visitDuration_fiO2Dial:
#   mean diff = 0.365; stdev diff = 3.404
#   Paired t-test:
#     |diff| > 0: p = 0.705
#     diff < 0: p = 0.647
#     diff > 0: p = 0.353
# visitDuration_spO2ReferenceTable:
#   mean diff = 0.207; stdev diff = 2.501
#   Paired t-test:
#     |diff| > 0: p = 0.770
#     diff < 0: p = 0.615
#     diff > 0: p = 0.385
# visitDuration_monitorFull:
#   mean diff = -6.955; stdev diff = 16.835
#   Paired t-test:
#    ~|diff| > 0: p = 0.160
#    *diff < 0: p = 0.080
#     diff > 0: p = 0.920
# visitDuration_monitorBlank:
#   mean diff = 4.311; stdev diff = 11.263
#   Paired t-test:
#    ~|diff| > 0: p = 0.191
#     diff < 0: p = 0.905
#    *diff > 0: p = 0.095
# visitDuration_monitorApgarTimer:
#   mean diff = 3.135; stdev diff = 7.374
#   Paired t-test:
#    ~|diff| > 0: p = 0.149
#     diff < 0: p = 0.925
#    *diff > 0: p = 0.075
# visitDuration_monitorHeartRate:
#   mean diff = 5.390; stdev diff = 12.641
#   Paired t-test:
#    ~|diff| > 0: p = 0.148
#     diff < 0: p = 0.926
#    *diff > 0: p = 0.074
# visitDuration_monitorSpO2:
#   mean diff = 7.811; stdev diff = 16.063
#   Paired t-test:
#    ~|diff| > 0: p = 0.103
#     diff < 0: p = 0.948
#    *diff > 0: p = 0.052
# visitDuration_combinedFiO2:
#   mean diff = -11.866; stdev diff = 10.068
#   Paired t-test:
#   **|diff| > 0: p = 0.001
#   **diff < 0: p = 0.000
#     diff > 0: p = 1.000
# visitDuration_combinedSpO2:
#   mean diff = -6.528; stdev diff = 16.955
#   Paired t-test:
#    ~|diff| > 0: p = 0.188
#    *diff < 0: p = 0.094
#     diff > 0: p = 0.906

# %% [markdown]
# Observations:
#
# * Subjects look at the monitor maybe more, the blank parts of the monitor maybe less, the apgar timer maybe less, the heart rate less, the SpO2 number maybe less, the combined FiO2 elements more, and the combined SpO2 elements maybe less in the full display than in the minimal display.

# %% [markdown]
# #### Summary
#
# *

# %% [markdown]
# ### Scenario Order Pairing, Split by Scenario

# %%
scenario_order_pairings = {
    0: statistics.build_pairing(scenario_pairing[0], 'scenarioNumber', values=(1, 4), check_validity=False),
    1: statistics.build_pairing(scenario_pairing[1], 'scenarioNumber', values=(2, 3), check_validity=False),
}

# %% [markdown]
# #### Easy Scenarios

# %%
scenario_order_pairings[0].describe()
# Out:
# Pairing against scenarioNumber:
#   0: first vs. 1: second
#   14 0 vs. 1 pairs.
#   Paired t-test alternative hypotheses:
#     Ha left-tailed (diff < 0): mean 0 - mean 1 < 0
#     Ha two-tailed (|diff| > 0): mean 0 - mean 1 != 0
#     Ha right-tailed (diff > 0): mean 0 - mean 1 > 0

# %%
statistics.test_gaze_duration_outcomes(scenario_order_pairings[0])
# Out:
# visitDuration_infant:
#   mean diff = 10.979; stdev diff = 14.322
#   Paired t-test:
#   **|diff| > 0: p = 0.016
#     diff < 0: p = 0.992
#   **diff > 0: p = 0.008
# visitDuration_warmerInstrumentPanel:
#   mean diff = 1.010; stdev diff = 8.013
#   Paired t-test:
#     |diff| > 0: p = 0.657
#     diff < 0: p = 0.671
#     diff > 0: p = 0.329
# visitDuration_fiO2Dial:
#   mean diff = 0.190; stdev diff = 5.229
#   Paired t-test:
#     |diff| > 0: p = 0.898
#     diff < 0: p = 0.551
#     diff > 0: p = 0.449
# visitDuration_spO2ReferenceTable:
#   mean diff = -1.297; stdev diff = 5.507
#   Paired t-test:
#     |diff| > 0: p = 0.411
#     diff < 0: p = 0.206
#     diff > 0: p = 0.794
# visitDuration_monitorFull:
#   mean diff = -15.070; stdev diff = 30.593
#   Paired t-test:
#    *|diff| > 0: p = 0.099
#   **diff < 0: p = 0.050
#     diff > 0: p = 0.950
# visitDuration_monitorBlank:
#   mean diff = 1.584; stdev diff = 6.787
#   Paired t-test:
#     |diff| > 0: p = 0.415
#     diff < 0: p = 0.792
#     diff > 0: p = 0.208
# visitDuration_monitorApgarTimer:
#   mean diff = -1.704; stdev diff = 9.302
#   Paired t-test:
#     |diff| > 0: p = 0.521
#     diff < 0: p = 0.260
#     diff > 0: p = 0.740
# visitDuration_monitorHeartRate:
#   mean diff = -3.222; stdev diff = 18.359
#   Paired t-test:
#     |diff| > 0: p = 0.538
#     diff < 0: p = 0.269
#     diff > 0: p = 0.731
# visitDuration_monitorSpO2:
#   mean diff = -5.261; stdev diff = 27.675
#   Paired t-test:
#     |diff| > 0: p = 0.505
#     diff < 0: p = 0.253
#     diff > 0: p = 0.747
# visitDuration_combinedFiO2:
#   mean diff = -0.068; stdev diff = 9.114
#   Paired t-test:
#     |diff| > 0: p = 0.979
#     diff < 0: p = 0.489
#     diff > 0: p = 0.511
# visitDuration_combinedSpO2:
#   mean diff = -11.618; stdev diff = 25.199
#   Paired t-test:
#    ~|diff| > 0: p = 0.120
#    *diff < 0: p = 0.060
#     diff > 0: p = 0.940

# %% [markdown]
# Observations:
#
# * Participants in scenario 1 look more at the infant, less at the monitor, and maybe less at combined SpO2 compared to scenario 4.
# * These results suggest an adaptation effect between scenarios 1 and 4.

# %% [markdown]
# #### Hard Scenarios

# %%
scenario_order_pairings[1].describe()
# Out:
# Pairing against scenarioNumber:
#   0: first vs. 1: second
#   14 0 vs. 1 pairs.
#   Paired t-test alternative hypotheses:
#     Ha left-tailed (diff < 0): mean 0 - mean 1 < 0
#     Ha two-tailed (|diff| > 0): mean 0 - mean 1 != 0
#     Ha right-tailed (diff > 0): mean 0 - mean 1 > 0

# %%
statistics.test_gaze_duration_outcomes(scenario_order_pairings[1])
# Out:
# visitDuration_infant:
#   mean diff = 6.517; stdev diff = 23.036
#   Paired t-test:
#     |diff| > 0: p = 0.326
#     diff < 0: p = 0.837
#    ~diff > 0: p = 0.163
# visitDuration_warmerInstrumentPanel:
#   mean diff = -3.867; stdev diff = 8.733
#   Paired t-test:
#    ~|diff| > 0: p = 0.134
#    *diff < 0: p = 0.067
#     diff > 0: p = 0.933
# visitDuration_fiO2Dial:
#   mean diff = -0.436; stdev diff = 3.396
#   Paired t-test:
#     |diff| > 0: p = 0.651
#     diff < 0: p = 0.325
#     diff > 0: p = 0.675
# visitDuration_spO2ReferenceTable:
#   mean diff = -0.924; stdev diff = 2.333
#   Paired t-test:
#    ~|diff| > 0: p = 0.177
#    *diff < 0: p = 0.088
#     diff > 0: p = 0.912
# visitDuration_monitorFull:
#   mean diff = -1.777; stdev diff = 18.128
#   Paired t-test:
#     |diff| > 0: p = 0.729
#     diff < 0: p = 0.365
#     diff > 0: p = 0.635
# visitDuration_monitorBlank:
#   mean diff = -7.099; stdev diff = 9.749
#   Paired t-test:
#   **|diff| > 0: p = 0.021
#   **diff < 0: p = 0.010
#     diff > 0: p = 0.990
# visitDuration_monitorApgarTimer:
#   mean diff = 3.995; stdev diff = 6.945
#   Paired t-test:
#    *|diff| > 0: p = 0.059
#     diff < 0: p = 0.971
#   **diff > 0: p = 0.029
# visitDuration_monitorHeartRate:
#   mean diff = 0.983; stdev diff = 13.707
#   Paired t-test:
#     |diff| > 0: p = 0.800
#     diff < 0: p = 0.600
#     diff > 0: p = 0.400
# visitDuration_monitorSpO2:
#   mean diff = 4.623; stdev diff = 17.253
#   Paired t-test:
#     |diff| > 0: p = 0.352
#     diff < 0: p = 0.824
#    ~diff > 0: p = 0.176
# visitDuration_combinedFiO2:
#   mean diff = -4.021; stdev diff = 15.033
#   Paired t-test:
#     |diff| > 0: p = 0.352
#    ~diff < 0: p = 0.176
#     diff > 0: p = 0.824
# visitDuration_combinedSpO2:
#   mean diff = 5.489; stdev diff = 17.320
#   Paired t-test:
#     |diff| > 0: p = 0.274
#     diff < 0: p = 0.863
#    ~diff > 0: p = 0.137

# %% [markdown]
# Observations:
#
# * Participants in scenario 2 look less at the blank part of the monitor, maybe more at the apgar timer, and maybe more at combined SpO2, and maybe less at the instrument panel compared to scenario 3.
# * These results are pretty weak but might suggest adaptation between scenarios 2 and 3.

# %% [markdown]
# #### Summary
#
# * There seems to be a learning effect between scenarios 1 and 4, but maybe not a strong effect between scenarios 2 and 3.

# %% [markdown]
# ## Correlations

# %%
GAZE_DURATION_OUTCOMES = [
    'visitDuration_infant',
    'visitDuration_warmerInstrumentPanel',
    # 'visitDuration_fiO2Dial',
    'visitDuration_spO2ReferenceTable',
    'visitDuration_monitorFull',
    'visitDuration_monitorBlank',
    'visitDuration_monitorApgarTimer',
    # 'visitDuration_monitorHeartRate',
    # 'visitDuration_monitorFiO2',
    'visitDuration_monitorGraph',
    'visitDuration_monitorSpO2',
    # 'visitDuration_combinedFiO2',
    'visitDuration_combinedSpO2'
]
outcomes_df = full_df[statistics.TRACING_OUTCOMES + GAZE_DURATION_OUTCOMES]

pd.plotting.scatter_matrix(outcomes_df, figsize=(36, 36))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa7d095a278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7ce68bc18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7ce5fb5c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7d0897e80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7d072cc18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7d072cc50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7d08d5278>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7d091a898>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7d07dffd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7ce58bf28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7ce544240>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa7ce4c0828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7ce4cfe80>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7ce404780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7ce3d4e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7ce34f588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7ce2ad828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7ce2294e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7ce207e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7ce1c6198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7ce1516a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7ce0e2ba8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa7ce01d4e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7d07d7b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cdfcc438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cdf23b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cde960f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cde75588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cddee240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cddceb70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cdd89f60>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cdc9b4e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cdca9470>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cdbe5240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cdbbf9e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cdb32080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cdb0f400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cda8b1d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cd9e99e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cd9a2dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cd934358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cd9472e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cd87f0b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cde0f4a8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cd7b5240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cd78d9b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cd701080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cd65f3c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cd5d9080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cd5b89b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cd573da0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cd504208>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cd514588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cd447f28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cd3a8828>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cd393eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cd2f8240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cd26bdd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cd253748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cd20ea20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cd195fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cd311588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cd063e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cd5f04e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7ccfa6780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7ccf7e3c8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa7ccef8198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cced58d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cce92be0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7ccda4198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7ccf906a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7ccce6f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cccc6748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7ccc31dd8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7ccb99160>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7ccb8cbe0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7ccaf2588>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa7ccaac860>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cca34e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7ccba96d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cc980b38>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cc8e1400>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cc8cd978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cc82add8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cc7a56d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cc78b240>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cc745518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cc6c2208>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cc70a518>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cc5ffef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cc55f6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cc54ac18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cc4b10b8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cc424a58>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cc4094e0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cc3c7ef0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cc34dd68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cc2e70f0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cc21ba90>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cc1f9358>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cc1638d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cc143d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cc0bf710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cc024198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cbfe0a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cbf69a20>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cbf7cc18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cbeb4748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cbe8bfd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cbdfe588>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cbd5d9e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cbcd73c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cbcb6e10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cbc7a780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cbc035c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cbc743c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cbb37828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cc444a90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cba7e080>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cb9da3c8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fa7cb9cdd68>]], dtype=object)

# %%
outcomes_df.corr('pearson')[statistics.TRACING_OUTCOMES]
# Out:
#                                      inSpO2TargetRangeDuration  \
# inSpO2TargetRangeDuration                             1.000000
# inSpO2LooseTargetRangeDuration                        0.639573
# visitDuration_infant                                 -0.405958
# visitDuration_warmerInstrumentPanel                  -0.058194
# visitDuration_spO2ReferenceTable                      0.126277
# visitDuration_monitorFull                             0.324619
# visitDuration_monitorBlank                           -0.034752
# visitDuration_monitorApgarTimer                       0.141052
# visitDuration_monitorGraph                            0.220376
# visitDuration_monitorSpO2                             0.275575
# visitDuration_combinedSpO2                            0.406695
#
#                                      inSpO2LooseTargetRangeDuration
# inSpO2TargetRangeDuration                                  0.639573
# inSpO2LooseTargetRangeDuration                             1.000000
# visitDuration_infant                                      -0.212828
# visitDuration_warmerInstrumentPanel                       -0.083227
# visitDuration_spO2ReferenceTable                           0.234202
# visitDuration_monitorFull                                  0.170862
# visitDuration_monitorBlank                                -0.086946
# visitDuration_monitorApgarTimer                           -0.035017
# visitDuration_monitorGraph                                 0.205960
# visitDuration_monitorSpO2                                  0.350128
# visitDuration_combinedSpO2                                 0.481128

# %%
outcomes_df.corr('spearman')[statistics.TRACING_OUTCOMES]
# Out:
#                                      inSpO2TargetRangeDuration  \
# inSpO2TargetRangeDuration                             1.000000
# inSpO2LooseTargetRangeDuration                        0.639535
# visitDuration_infant                                 -0.392578
# visitDuration_warmerInstrumentPanel                  -0.097754
# visitDuration_spO2ReferenceTable                      0.247768
# visitDuration_monitorFull                             0.342565
# visitDuration_monitorBlank                           -0.006978
# visitDuration_monitorApgarTimer                       0.079530
# visitDuration_monitorGraph                            0.034682
# visitDuration_monitorSpO2                             0.281695
# visitDuration_combinedSpO2                            0.393060
#
#                                      inSpO2LooseTargetRangeDuration
# inSpO2TargetRangeDuration                                  0.639535
# inSpO2LooseTargetRangeDuration                             1.000000
# visitDuration_infant                                      -0.172852
# visitDuration_warmerInstrumentPanel                       -0.093679
# visitDuration_spO2ReferenceTable                           0.257742
# visitDuration_monitorFull                                  0.171110
# visitDuration_monitorBlank                                -0.102478
# visitDuration_monitorApgarTimer                            0.011847
# visitDuration_monitorGraph                                 0.145730
# visitDuration_monitorSpO2                                  0.328219
# visitDuration_combinedSpO2                                 0.521535
