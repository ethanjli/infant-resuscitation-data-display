# %% [markdown]
# # Imports

# %%
# %matplotlib inline

import scipy as sp
from scipy import stats
import numpy as np
import pandas as pd

import statistics

# %% [markdown]
# # Load Data

# %%
tracing_df = statistics.load_tracing_features()
recording_df = statistics.load_recording_relations()
recording_df = statistics.associate_recordings(recording_df, tracing_df)
gaze_dfs = statistics.load_gaze_features()
statistics.check_gaze_recording_associations(recording_df, gaze_dfs)
statistics.compute_gaze_features(gaze_dfs)
gaze_df = statistics.combine_gaze_features(gaze_dfs)
full_df = statistics.combine_all_features(recording_df, gaze_df)
full_df.columns
# Out:
# Index(['id', 'subjectNumber', 'scenarioNumber', 'newAfterOld', 'scenarioType',
#        'displayType', 'sensorPlacementTime', 'ppvStartTime', 'ccStartTime',
#        'inSpO2TargetRangeDuration', 'inSpO2LooseTargetRangeDuration',
#        'inSpO2TargetRangeStartTime', 'aboveSpO2TargetRangeDuration',
#        'belowSpO2TargetRangeDuration', 'inFiO2TargetRangeDuration',
#        'inFiO2TargetRangeStartTime', 'aboveFiO2TargetRangeDuration',
#        'belowFiO2TargetRangeDuration', 'spO2SignedErrorIntegral',
#        'spO2UnsignedErrorIntegral', 'spO2SquaredErrorIntegral',
#        'fiO2LargeAdjustments', 'visitDuration_fiO2Dial',
#        'visitDuration_infant', 'visitDuration_monitorApgarTimer',
#        'visitDuration_monitorBlank', 'visitDuration_monitorFiO2',
#        'visitDuration_monitorFull', 'visitDuration_monitorGraph',
#        'visitDuration_monitorHeartRate', 'visitDuration_monitorSpO2',
#        'visitDuration_spO2ReferenceTable',
#        'visitDuration_warmerInstrumentPanel', 'visitDuration_combinedFiO2',
#        'visitDuration_combinedSpO2', 'visitCount_fiO2Dial',
#        'visitCount_infant', 'visitCount_monitorApgarTimer',
#        'visitCount_monitorBlank', 'visitCount_monitorFiO2',
#        'visitCount_monitorFull', 'visitCount_monitorGraph',
#        'visitCount_monitorHeartRate', 'visitCount_monitorSpO2',
#        'visitCount_spO2ReferenceTable', 'visitCount_warmerInstrumentPanel',
#        'visitCount_combinedFiO2', 'visitCount_combinedSpO2'],
#       dtype='object')

# %% [markdown]
# # Pairing

# %% [markdown]
# ### Scenario Type Pairing

# %%
scenario_pairing = statistics.build_pairing(full_df, 'scenarioType')

# %%
scenario_pairing.describe()
# Out:
# Pairing against scenarioType:
#   0: easy vs. 1: hard
#   22 0 vs. 1 pairs.
#   Paired t-test alternative hypotheses:
#     Ha left-tailed (diff < 0): mean 0 - mean 1 < 0
#     Ha two-tailed (|diff| > 0): mean 0 - mean 1 != 0
#     Ha right-tailed (diff > 0): mean 0 - mean 1 > 0
#   Wilcoxon signed-rank alternative hypotheses:
#     Ha left-tailed (P(x > y) < 0.5)
#     Ha two-tailed (P(x > y) != 0.5)
#     Ha right-tailed (P(x > y) > 0.5)

# %%
statistics.test_gaze_duration_outcomes(scenario_pairing)
# Out:
# visitDuration_infant:
#   mean diff = -13.453; stdev diff = 24.960
#   Paired t-test:
#   **|diff| > 0: p = 0.022
#   **diff < 0: p = 0.011
#     diff > 0: p = 0.989
#   Wilcoxon signed-rank test:
#   **P(x > y) != 0.5: p = 0.033
#   **P(x > y) < 0.5: p = 0.017
#     P(x > y) > 0.5: p = 0.983
# visitDuration_warmerInstrumentPanel:
#   mean diff = 1.327; stdev diff = 8.296
#   Paired t-test:
#     |diff| > 0: p = 0.472
#     diff < 0: p = 0.764
#     diff > 0: p = 0.236
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.355
#     P(x > y) < 0.5: p = 0.823
#    ~P(x > y) > 0.5: p = 0.177
# visitDuration_fiO2Dial:
#   mean diff = 2.428; stdev diff = 5.650
#   Paired t-test:
#    *|diff| > 0: p = 0.062
#     diff < 0: p = 0.969
#   **diff > 0: p = 0.031
#   Wilcoxon signed-rank test:
#    ~P(x > y) != 0.5: p = 0.168
#     P(x > y) < 0.5: p = 0.916
#    *P(x > y) > 0.5: p = 0.084
# visitDuration_spO2ReferenceTable:
#   mean diff = 4.176; stdev diff = 6.495
#   Paired t-test:
#   **|diff| > 0: p = 0.008
#     diff < 0: p = 0.996
#   **diff > 0: p = 0.004
#   Wilcoxon signed-rank test:
#   **P(x > y) != 0.5: p = 0.011
#     P(x > y) < 0.5: p = 0.995
#   **P(x > y) > 0.5: p = 0.005
# visitDuration_monitorFull:
#   mean diff = -1.664; stdev diff = 24.617
#   Paired t-test:
#     |diff| > 0: p = 0.760
#     diff < 0: p = 0.380
#     diff > 0: p = 0.620
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.910
#     P(x > y) < 0.5: p = 0.455
#     P(x > y) > 0.5: p = 0.545
# visitDuration_monitorBlank:
#   mean diff = -2.637; stdev diff = 7.951
#   Paired t-test:
#    ~|diff| > 0: p = 0.144
#    *diff < 0: p = 0.072
#     diff > 0: p = 0.928
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.211
#    ~P(x > y) < 0.5: p = 0.106
#     P(x > y) > 0.5: p = 0.894
# visitDuration_monitorApgarTimer:
#   mean diff = -0.574; stdev diff = 4.956
#   Paired t-test:
#     |diff| > 0: p = 0.601
#     diff < 0: p = 0.301
#     diff > 0: p = 0.699
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.987
#     P(x > y) < 0.5: p = 0.494
#     P(x > y) > 0.5: p = 0.506
# visitDuration_monitorHeartRate:
#   mean diff = -8.622; stdev diff = 16.544
#   Paired t-test:
#   **|diff| > 0: p = 0.026
#   **diff < 0: p = 0.013
#     diff > 0: p = 0.987
#   Wilcoxon signed-rank test:
#   **P(x > y) != 0.5: p = 0.013
#   **P(x > y) < 0.5: p = 0.007
#     P(x > y) > 0.5: p = 0.993
# visitDuration_monitorFiO2:
#   mean diff = -1.644; stdev diff = 6.239
#   Paired t-test:
#     |diff| > 0: p = 0.241
#    ~diff < 0: p = 0.120
#     diff > 0: p = 0.880
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.594
#     P(x > y) < 0.5: p = 0.297
#     P(x > y) > 0.5: p = 0.703
# visitDuration_monitorGraph:
#   mean diff = 6.411; stdev diff = 16.210
#   Paired t-test:
#    *|diff| > 0: p = 0.084
#     diff < 0: p = 0.958
#   **diff > 0: p = 0.042
#   Wilcoxon signed-rank test:
#    *P(x > y) != 0.5: p = 0.075
#     P(x > y) < 0.5: p = 0.962
#   **P(x > y) > 0.5: p = 0.038
# visitDuration_monitorSpO2:
#   mean diff = 3.102; stdev diff = 18.015
#   Paired t-test:
#     |diff| > 0: p = 0.439
#     diff < 0: p = 0.781
#     diff > 0: p = 0.219
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.733
#     P(x > y) < 0.5: p = 0.633
#     P(x > y) > 0.5: p = 0.367
# visitDuration_combinedFiO2:
#   mean diff = 0.783; stdev diff = 9.219
#   Paired t-test:
#     |diff| > 0: p = 0.701
#     diff < 0: p = 0.650
#     diff > 0: p = 0.350
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.426
#     P(x > y) < 0.5: p = 0.787
#     P(x > y) > 0.5: p = 0.213
# visitDuration_combinedSpO2:
#   mean diff = 13.689; stdev diff = 25.473
#   Paired t-test:
#   **|diff| > 0: p = 0.023
#     diff < 0: p = 0.989
#   **diff > 0: p = 0.011
#   Wilcoxon signed-rank test:
#   **P(x > y) != 0.5: p = 0.036
#     P(x > y) < 0.5: p = 0.982
#   **P(x > y) > 0.5: p = 0.018

# %% [markdown]
# Observations:
#
# * Wilcoxon signed-rank and paired t-tests seem to behave generally the same way.
# * Subjects look at the infant less, the FiO2 dial more, the SpO2 reference table more, the heart rate less, the graph more, and the combined SpO2 elements more in the easy scenario than in the hard scenario.

# %% [markdown]
# ### Display Type Pairing

# %%
display_pairing = statistics.build_pairing(full_df, 'displayType')

# %%
display_pairing.describe()
# Out:
# Pairing against displayType:
#   0: minimal vs. 1: full
#   26 0 vs. 1 pairs.
#   Paired t-test alternative hypotheses:
#     Ha left-tailed (diff < 0): mean 0 - mean 1 < 0
#     Ha two-tailed (|diff| > 0): mean 0 - mean 1 != 0
#     Ha right-tailed (diff > 0): mean 0 - mean 1 > 0
#   Wilcoxon signed-rank alternative hypotheses:
#     Ha left-tailed (P(x > y) < 0.5)
#     Ha two-tailed (P(x > y) != 0.5)
#     Ha right-tailed (P(x > y) > 0.5)

# %%
statistics.test_gaze_duration_outcomes(display_pairing)
# Out:
# visitDuration_infant:
#   mean diff = 0.480; stdev diff = 23.748
#   Paired t-test:
#     |diff| > 0: p = 0.920
#     diff < 0: p = 0.540
#     diff > 0: p = 0.460
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.713
#     P(x > y) < 0.5: p = 0.644
#     P(x > y) > 0.5: p = 0.356
# visitDuration_warmerInstrumentPanel:
#   mean diff = -0.173; stdev diff = 9.184
#   Paired t-test:
#     |diff| > 0: p = 0.926
#     diff < 0: p = 0.463
#     diff > 0: p = 0.537
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.770
#     P(x > y) < 0.5: p = 0.385
#     P(x > y) > 0.5: p = 0.615
# visitDuration_fiO2Dial:
#   mean diff = 0.986; stdev diff = 5.208
#   Paired t-test:
#     |diff| > 0: p = 0.353
#     diff < 0: p = 0.824
#    ~diff > 0: p = 0.176
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.316
#     P(x > y) < 0.5: p = 0.842
#    ~P(x > y) > 0.5: p = 0.158
# visitDuration_spO2ReferenceTable:
#   mean diff = 0.851; stdev diff = 4.313
#   Paired t-test:
#     |diff| > 0: p = 0.334
#     diff < 0: p = 0.833
#    ~diff > 0: p = 0.167
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.459
#     P(x > y) < 0.5: p = 0.770
#     P(x > y) > 0.5: p = 0.230
# visitDuration_monitorFull:
#   mean diff = -8.560; stdev diff = 28.623
#   Paired t-test:
#    ~|diff| > 0: p = 0.147
#    *diff < 0: p = 0.074
#     diff > 0: p = 0.926
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.395
#    ~P(x > y) < 0.5: p = 0.197
#     P(x > y) > 0.5: p = 0.803
# visitDuration_monitorBlank:
#   mean diff = 3.135; stdev diff = 9.927
#   Paired t-test:
#    ~|diff| > 0: p = 0.127
#     diff < 0: p = 0.937
#    *diff > 0: p = 0.063
#   Wilcoxon signed-rank test:
#    ~P(x > y) != 0.5: p = 0.124
#     P(x > y) < 0.5: p = 0.938
#    *P(x > y) > 0.5: p = 0.062
# visitDuration_monitorApgarTimer:
#   mean diff = 4.735; stdev diff = 9.187
#   Paired t-test:
#   **|diff| > 0: p = 0.016
#     diff < 0: p = 0.992
#   **diff > 0: p = 0.008
#   Wilcoxon signed-rank test:
#   **P(x > y) != 0.5: p = 0.004
#     P(x > y) < 0.5: p = 0.998
#   **P(x > y) > 0.5: p = 0.002
# visitDuration_monitorHeartRate:
#   mean diff = 8.823; stdev diff = 13.517
#   Paired t-test:
#   **|diff| > 0: p = 0.003
#     diff < 0: p = 0.998
#   **diff > 0: p = 0.002
#   Wilcoxon signed-rank test:
#   **P(x > y) != 0.5: p = 0.004
#     P(x > y) < 0.5: p = 0.998
#   **P(x > y) > 0.5: p = 0.002
# visitDuration_monitorFiO2:
#   mean diff = -9.872; stdev diff = 7.829
#   Paired t-test:
#   **|diff| > 0: p = 0.000
#   **diff < 0: p = 0.000
#     diff > 0: p = 1.000
#   Wilcoxon signed-rank test:
#   **P(x > y) != 0.5: p = 0.000
#   **P(x > y) < 0.5: p = 0.000
#     P(x > y) > 0.5: p = 1.000
# visitDuration_monitorGraph:
#   mean diff = -23.304; stdev diff = 17.634
#   Paired t-test:
#   **|diff| > 0: p = 0.000
#   **diff < 0: p = 0.000
#     diff > 0: p = 1.000
#   Wilcoxon signed-rank test:
#   **P(x > y) != 0.5: p = 0.000
#   **P(x > y) < 0.5: p = 0.000
#     P(x > y) > 0.5: p = 1.000
# visitDuration_monitorSpO2:
#   mean diff = 8.586; stdev diff = 21.919
#   Paired t-test:
#    *|diff| > 0: p = 0.061
#     diff < 0: p = 0.969
#   **diff > 0: p = 0.031
#   Wilcoxon signed-rank test:
#    *P(x > y) != 0.5: p = 0.086
#     P(x > y) < 0.5: p = 0.957
#   **P(x > y) > 0.5: p = 0.043
# visitDuration_combinedFiO2:
#   mean diff = -8.886; stdev diff = 9.499
#   Paired t-test:
#   **|diff| > 0: p = 0.000
#   **diff < 0: p = 0.000
#     diff > 0: p = 1.000
#   Wilcoxon signed-rank test:
#   **P(x > y) != 0.5: p = 0.000
#   **P(x > y) < 0.5: p = 0.000
#     P(x > y) > 0.5: p = 1.000
# visitDuration_combinedSpO2:
#   mean diff = -13.868; stdev diff = 21.037
#   Paired t-test:
#   **|diff| > 0: p = 0.003
#   **diff < 0: p = 0.001
#     diff > 0: p = 0.999
#   Wilcoxon signed-rank test:
#   **P(x > y) != 0.5: p = 0.005
#   **P(x > y) < 0.5: p = 0.003
#     P(x > y) > 0.5: p = 0.997

# %% [markdown]
# Observations:
#
# * Wilcoxon signed-rank and paired t-tests seem to behave generally the same way.
# * Subjects look at the apgar timer less, the heart rate less, the SpO2 less, the combined FiO2 more, and the combined SpO2 more in the full display than in the minimal display.

# %% [markdown]
# ### Display Type Pairing, Split by Scenario

# %%
scenario_display_pairings = {
    scenario: statistics.build_pairing(scenario_subset, 'displayType')
    for (scenario, scenario_subset) in enumerate(scenario_pairing)
}

# %% [markdown]
# #### Easy Scenarios

# %%
scenario_display_pairings[0].describe()
# Out:
# Pairing against displayType:
#   0: minimal vs. 1: full
#   11 0 vs. 1 pairs.
#   Paired t-test alternative hypotheses:
#     Ha left-tailed (diff < 0): mean 0 - mean 1 < 0
#     Ha two-tailed (|diff| > 0): mean 0 - mean 1 != 0
#     Ha right-tailed (diff > 0): mean 0 - mean 1 > 0
#   Wilcoxon signed-rank alternative hypotheses:
#     Ha left-tailed (P(x > y) < 0.5)
#     Ha two-tailed (P(x > y) != 0.5)
#     Ha right-tailed (P(x > y) > 0.5)

# %%
statistics.test_gaze_duration_outcomes(scenario_display_pairings[0])
# Out:
# visitDuration_infant:
#   mean diff = -0.642; stdev diff = 19.301
#   Paired t-test:
#     |diff| > 0: p = 0.918
#     diff < 0: p = 0.459
#     diff > 0: p = 0.541
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 1.000
#     P(x > y) < 0.5: p = 0.500
#     P(x > y) > 0.5: p = 0.500
# visitDuration_warmerInstrumentPanel:
#   mean diff = 0.203; stdev diff = 8.799
#   Paired t-test:
#     |diff| > 0: p = 0.943
#     diff < 0: p = 0.528
#     diff > 0: p = 0.472
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.929
#     P(x > y) < 0.5: p = 0.535
#     P(x > y) > 0.5: p = 0.465
# visitDuration_fiO2Dial:
#   mean diff = 1.118; stdev diff = 5.596
#   Paired t-test:
#     |diff| > 0: p = 0.542
#     diff < 0: p = 0.729
#     diff > 0: p = 0.271
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.286
#     P(x > y) < 0.5: p = 0.857
#    ~P(x > y) > 0.5: p = 0.143
# visitDuration_spO2ReferenceTable:
#   mean diff = -0.285; stdev diff = 5.330
#   Paired t-test:
#     |diff| > 0: p = 0.869
#     diff < 0: p = 0.434
#     diff > 0: p = 0.566
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.657
#     P(x > y) < 0.5: p = 0.328
#     P(x > y) > 0.5: p = 0.672
# visitDuration_monitorFull:
#   mean diff = -9.335; stdev diff = 34.942
#   Paired t-test:
#     |diff| > 0: p = 0.418
#     diff < 0: p = 0.209
#     diff > 0: p = 0.791
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.594
#     P(x > y) < 0.5: p = 0.297
#     P(x > y) > 0.5: p = 0.703
# visitDuration_monitorBlank:
#   mean diff = 1.672; stdev diff = 6.567
#   Paired t-test:
#     |diff| > 0: p = 0.439
#     diff < 0: p = 0.780
#     diff > 0: p = 0.220
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.248
#     P(x > y) < 0.5: p = 0.876
#    ~P(x > y) > 0.5: p = 0.124
# visitDuration_monitorApgarTimer:
#   mean diff = 3.863; stdev diff = 5.579
#   Paired t-test:
#    *|diff| > 0: p = 0.053
#     diff < 0: p = 0.973
#   **diff > 0: p = 0.027
#   Wilcoxon signed-rank test:
#    *P(x > y) != 0.5: p = 0.062
#     P(x > y) < 0.5: p = 0.969
#   **P(x > y) > 0.5: p = 0.031
# visitDuration_monitorHeartRate:
#   mean diff = 9.612; stdev diff = 17.537
#   Paired t-test:
#    ~|diff| > 0: p = 0.114
#     diff < 0: p = 0.943
#    *diff > 0: p = 0.057
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.248
#     P(x > y) < 0.5: p = 0.876
#    ~P(x > y) > 0.5: p = 0.124
# visitDuration_monitorFiO2:
#   mean diff = -8.136; stdev diff = 4.423
#   Paired t-test:
#   **|diff| > 0: p = 0.000
#   **diff < 0: p = 0.000
#     diff > 0: p = 1.000
#   Wilcoxon signed-rank test:
#   **P(x > y) != 0.5: p = 0.003
#   **P(x > y) < 0.5: p = 0.002
#     P(x > y) > 0.5: p = 0.998
# visitDuration_monitorGraph:
#   mean diff = -27.114; stdev diff = 20.598
#   Paired t-test:
#   **|diff| > 0: p = 0.002
#   **diff < 0: p = 0.001
#     diff > 0: p = 0.999
#   Wilcoxon signed-rank test:
#   **P(x > y) != 0.5: p = 0.003
#   **P(x > y) < 0.5: p = 0.002
#     P(x > y) > 0.5: p = 0.998
# visitDuration_monitorSpO2:
#   mean diff = 11.065; stdev diff = 27.816
#   Paired t-test:
#     |diff| > 0: p = 0.237
#     diff < 0: p = 0.881
#    ~diff > 0: p = 0.119
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.286
#     P(x > y) < 0.5: p = 0.857
#    ~P(x > y) > 0.5: p = 0.143
# visitDuration_combinedFiO2:
#   mean diff = -7.018; stdev diff = 6.068
#   Paired t-test:
#   **|diff| > 0: p = 0.004
#   **diff < 0: p = 0.002
#     diff > 0: p = 0.998
#   Wilcoxon signed-rank test:
#   **P(x > y) != 0.5: p = 0.008
#   **P(x > y) < 0.5: p = 0.004
#     P(x > y) > 0.5: p = 0.996
# visitDuration_combinedSpO2:
#   mean diff = -16.335; stdev diff = 25.244
#   Paired t-test:
#    *|diff| > 0: p = 0.068
#   **diff < 0: p = 0.034
#     diff > 0: p = 0.966
#   Wilcoxon signed-rank test:
#    *P(x > y) != 0.5: p = 0.062
#   **P(x > y) < 0.5: p = 0.031
#     P(x > y) > 0.5: p = 0.969

# %% [markdown]
# Observations:
#
# * Wilcoxon signed-rank and paired t-tests seem to behave generally the same way.
# * Subjects look at the apgar timer less, the combined FiO2 more, and the combined SpO2 more in the full display than in the minimal display. They maybe look at the heart rate less.
# * This is generally similar to the results for easy and hard scenarios combined, but with fewer significantly different outcomes.

# %% [markdown]
# #### Hard Scenarios

# %%
scenario_display_pairings[1].describe()
# Out:
# Pairing against displayType:
#   0: minimal vs. 1: full
#   11 0 vs. 1 pairs.
#   Paired t-test alternative hypotheses:
#     Ha left-tailed (diff < 0): mean 0 - mean 1 < 0
#     Ha two-tailed (|diff| > 0): mean 0 - mean 1 != 0
#     Ha right-tailed (diff > 0): mean 0 - mean 1 > 0
#   Wilcoxon signed-rank alternative hypotheses:
#     Ha left-tailed (P(x > y) < 0.5)
#     Ha two-tailed (P(x > y) != 0.5)
#     Ha right-tailed (P(x > y) > 0.5)

# %%
statistics.test_gaze_duration_outcomes(scenario_display_pairings[1])
# Out:
# visitDuration_infant:
#   mean diff = -2.841; stdev diff = 24.110
#   Paired t-test:
#     |diff| > 0: p = 0.717
#     diff < 0: p = 0.359
#     diff > 0: p = 0.641
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.859
#     P(x > y) < 0.5: p = 0.429
#     P(x > y) > 0.5: p = 0.571
# visitDuration_warmerInstrumentPanel:
#   mean diff = 0.745; stdev diff = 10.132
#   Paired t-test:
#     |diff| > 0: p = 0.821
#     diff < 0: p = 0.590
#     diff > 0: p = 0.410
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.790
#     P(x > y) < 0.5: p = 0.605
#     P(x > y) > 0.5: p = 0.395
# visitDuration_fiO2Dial:
#   mean diff = -0.367; stdev diff = 3.074
#   Paired t-test:
#     |diff| > 0: p = 0.713
#     diff < 0: p = 0.357
#     diff > 0: p = 0.643
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.790
#     P(x > y) < 0.5: p = 0.395
#     P(x > y) > 0.5: p = 0.605
# visitDuration_spO2ReferenceTable:
#   mean diff = 0.720; stdev diff = 2.121
#   Paired t-test:
#     |diff| > 0: p = 0.308
#     diff < 0: p = 0.846
#    ~diff > 0: p = 0.154
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.248
#     P(x > y) < 0.5: p = 0.876
#    ~P(x > y) > 0.5: p = 0.124
# visitDuration_monitorFull:
#   mean diff = -4.988; stdev diff = 18.235
#   Paired t-test:
#     |diff| > 0: p = 0.407
#     diff < 0: p = 0.204
#     diff > 0: p = 0.796
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.657
#     P(x > y) < 0.5: p = 0.328
#     P(x > y) > 0.5: p = 0.672
# visitDuration_monitorBlank:
#   mean diff = 4.931; stdev diff = 12.612
#   Paired t-test:
#     |diff| > 0: p = 0.245
#     diff < 0: p = 0.878
#    ~diff > 0: p = 0.122
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.248
#     P(x > y) < 0.5: p = 0.876
#    ~P(x > y) > 0.5: p = 0.124
# visitDuration_monitorApgarTimer:
#   mean diff = 1.727; stdev diff = 7.068
#   Paired t-test:
#     |diff| > 0: p = 0.458
#     diff < 0: p = 0.771
#     diff > 0: p = 0.229
#   Wilcoxon signed-rank test:
#    ~P(x > y) != 0.5: p = 0.182
#     P(x > y) < 0.5: p = 0.909
#    *P(x > y) > 0.5: p = 0.091
# visitDuration_monitorHeartRate:
#   mean diff = 9.407; stdev diff = 6.391
#   Paired t-test:
#   **|diff| > 0: p = 0.001
#     diff < 0: p = 1.000
#   **diff > 0: p = 0.000
#   Wilcoxon signed-rank test:
#   **P(x > y) != 0.5: p = 0.008
#     P(x > y) < 0.5: p = 0.996
#   **P(x > y) > 0.5: p = 0.004
# visitDuration_monitorFiO2:
#   mean diff = -11.424; stdev diff = 10.432
#   Paired t-test:
#   **|diff| > 0: p = 0.006
#   **diff < 0: p = 0.003
#     diff > 0: p = 0.997
#   Wilcoxon signed-rank test:
#   **P(x > y) != 0.5: p = 0.003
#   **P(x > y) < 0.5: p = 0.002
#     P(x > y) > 0.5: p = 0.998
# visitDuration_monitorGraph:
#   mean diff = -14.293; stdev diff = 8.470
#   Paired t-test:
#   **|diff| > 0: p = 0.000
#   **diff < 0: p = 0.000
#     diff > 0: p = 1.000
#   Wilcoxon signed-rank test:
#   **P(x > y) != 0.5: p = 0.003
#   **P(x > y) < 0.5: p = 0.002
#     P(x > y) > 0.5: p = 0.998
# visitDuration_monitorSpO2:
#   mean diff = 4.813; stdev diff = 16.786
#   Paired t-test:
#     |diff| > 0: p = 0.386
#     diff < 0: p = 0.807
#    ~diff > 0: p = 0.193
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.374
#     P(x > y) < 0.5: p = 0.813
#    ~P(x > y) > 0.5: p = 0.187
# visitDuration_combinedFiO2:
#   mean diff = -11.792; stdev diff = 11.091
#   Paired t-test:
#   **|diff| > 0: p = 0.007
#   **diff < 0: p = 0.004
#     diff > 0: p = 0.996
#   Wilcoxon signed-rank test:
#   **P(x > y) != 0.5: p = 0.010
#   **P(x > y) < 0.5: p = 0.005
#     P(x > y) > 0.5: p = 0.995
# visitDuration_combinedSpO2:
#   mean diff = -8.760; stdev diff = 16.782
#   Paired t-test:
#    ~|diff| > 0: p = 0.130
#    *diff < 0: p = 0.065
#     diff > 0: p = 0.935
#   Wilcoxon signed-rank test:
#    ~P(x > y) != 0.5: p = 0.182
#    *P(x > y) < 0.5: p = 0.091
#     P(x > y) > 0.5: p = 0.909

# %% [markdown]
# Observations:
#
# * Wilcoxon signed-rank and paired t-tests seem to behave generally the same way.
# * Subjects look at the heart rate less and the combined FiO2 more in the full display than in the minimal display. They maybe look at the combined SpO2 more in the full display than in the minimal display.
# * This is similar to the results for easy and hard scenarios combined only for the combined FiO2 test.

# %% [markdown]
# #### Summary
#
# * In both scenario types, subjects look at the combined FiO2 more with the full display (which shows FiO2 reading) than with the minimal display (which doesn't show FiO2 reading)
# * In the easy scenario type, subjects look at the combined SpO2 more with the full display (which shows SpO2 graph) than with the minimal display (which doesn't show SpO2 graph).  In the hard scenario type, they might also look at combined SpO2 more.

# %% [markdown]
# ### Scenario Order Pairing, Split by Scenario

# %%
scenario_order_pairings = {
    0: statistics.build_pairing(scenario_pairing[0], 'scenarioNumber', values=(1, 4), check_validity=False),
    1: statistics.build_pairing(scenario_pairing[1], 'scenarioNumber', values=(2, 3), check_validity=False),
}

# %% [markdown]
# #### Easy Scenarios

# %%
scenario_order_pairings[0].describe()
# Out:
# Pairing against scenarioNumber:
#   0: first vs. 1: second
#   11 0 vs. 1 pairs.
#   Paired t-test alternative hypotheses:
#     Ha left-tailed (diff < 0): mean 0 - mean 1 < 0
#     Ha two-tailed (|diff| > 0): mean 0 - mean 1 != 0
#     Ha right-tailed (diff > 0): mean 0 - mean 1 > 0
#   Wilcoxon signed-rank alternative hypotheses:
#     Ha left-tailed (P(x > y) < 0.5)
#     Ha two-tailed (P(x > y) != 0.5)
#     Ha right-tailed (P(x > y) > 0.5)

# %%
statistics.test_gaze_duration_outcomes(scenario_order_pairings[0])
# Out:
# visitDuration_infant:
#   mean diff = 14.653; stdev diff = 12.579
#   Paired t-test:
#   **|diff| > 0: p = 0.004
#     diff < 0: p = 0.998
#   **diff > 0: p = 0.002
#   Wilcoxon signed-rank test:
#   **P(x > y) != 0.5: p = 0.013
#     P(x > y) < 0.5: p = 0.994
#   **P(x > y) > 0.5: p = 0.006
# visitDuration_warmerInstrumentPanel:
#   mean diff = 0.247; stdev diff = 8.798
#   Paired t-test:
#     |diff| > 0: p = 0.931
#     diff < 0: p = 0.535
#     diff > 0: p = 0.465
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.286
#     P(x > y) < 0.5: p = 0.857
#    ~P(x > y) > 0.5: p = 0.143
# visitDuration_fiO2Dial:
#   mean diff = 0.863; stdev diff = 5.641
#   Paired t-test:
#     |diff| > 0: p = 0.639
#     diff < 0: p = 0.681
#     diff > 0: p = 0.319
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.594
#     P(x > y) < 0.5: p = 0.703
#     P(x > y) > 0.5: p = 0.297
# visitDuration_spO2ReferenceTable:
#   mean diff = -0.213; stdev diff = 5.334
#   Paired t-test:
#     |diff| > 0: p = 0.902
#     diff < 0: p = 0.451
#     diff > 0: p = 0.549
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.790
#     P(x > y) < 0.5: p = 0.395
#     P(x > y) > 0.5: p = 0.605
# visitDuration_monitorFull:
#   mean diff = -22.192; stdev diff = 28.558
#   Paired t-test:
#   **|diff| > 0: p = 0.034
#   **diff < 0: p = 0.017
#     diff > 0: p = 0.983
#   Wilcoxon signed-rank test:
#   **P(x > y) != 0.5: p = 0.016
#   **P(x > y) < 0.5: p = 0.008
#     P(x > y) > 0.5: p = 0.992
# visitDuration_monitorBlank:
#   mean diff = 0.734; stdev diff = 6.737
#   Paired t-test:
#     |diff| > 0: p = 0.737
#     diff < 0: p = 0.631
#     diff > 0: p = 0.369
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.929
#     P(x > y) < 0.5: p = 0.535
#     P(x > y) > 0.5: p = 0.465
# visitDuration_monitorApgarTimer:
#   mean diff = -0.892; stdev diff = 6.727
#   Paired t-test:
#     |diff| > 0: p = 0.684
#     diff < 0: p = 0.342
#     diff > 0: p = 0.658
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.657
#     P(x > y) < 0.5: p = 0.328
#     P(x > y) > 0.5: p = 0.672
# visitDuration_monitorHeartRate:
#   mean diff = -5.849; stdev diff = 19.124
#   Paired t-test:
#     |diff| > 0: p = 0.356
#    ~diff < 0: p = 0.178
#     diff > 0: p = 0.822
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.424
#     P(x > y) < 0.5: p = 0.212
#     P(x > y) > 0.5: p = 0.788
# visitDuration_monitorFiO2:
#   mean diff = 0.131; stdev diff = 9.260
#   Paired t-test:
#     |diff| > 0: p = 0.965
#     diff < 0: p = 0.517
#     diff > 0: p = 0.483
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.929
#     P(x > y) < 0.5: p = 0.535
#     P(x > y) > 0.5: p = 0.465
# visitDuration_monitorGraph:
#   mean diff = -4.992; stdev diff = 33.683
#   Paired t-test:
#     |diff| > 0: p = 0.649
#     diff < 0: p = 0.325
#     diff > 0: p = 0.675
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.929
#     P(x > y) < 0.5: p = 0.465
#     P(x > y) > 0.5: p = 0.535
# visitDuration_monitorSpO2:
#   mean diff = -7.392; stdev diff = 29.009
#   Paired t-test:
#     |diff| > 0: p = 0.439
#     diff < 0: p = 0.220
#     diff > 0: p = 0.780
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.328
#    ~P(x > y) < 0.5: p = 0.164
#     P(x > y) > 0.5: p = 0.836
# visitDuration_combinedFiO2:
#   mean diff = 0.994; stdev diff = 9.224
#   Paired t-test:
#     |diff| > 0: p = 0.740
#     diff < 0: p = 0.630
#     diff > 0: p = 0.370
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.657
#     P(x > y) < 0.5: p = 0.672
#     P(x > y) > 0.5: p = 0.328
# visitDuration_combinedSpO2:
#   mean diff = -12.597; stdev diff = 27.302
#   Paired t-test:
#    ~|diff| > 0: p = 0.175
#    *diff < 0: p = 0.088
#     diff > 0: p = 0.912
#   Wilcoxon signed-rank test:
#    ~P(x > y) != 0.5: p = 0.155
#    *P(x > y) < 0.5: p = 0.077
#     P(x > y) > 0.5: p = 0.923

# %% [markdown]
# Observations:
#
# * Participants in scenario 1 look more at the infant, less at the monitor, and maybe less at combined SpO2 compared to scenario 4.
# * These results suggest an adaptation effect between scenarios 1 and 4.

# %% [markdown]
# #### Hard Scenarios

# %%
scenario_order_pairings[1].describe()
# Out:
# Pairing against scenarioNumber:
#   0: first vs. 1: second
#   11 0 vs. 1 pairs.
#   Paired t-test alternative hypotheses:
#     Ha left-tailed (diff < 0): mean 0 - mean 1 < 0
#     Ha two-tailed (|diff| > 0): mean 0 - mean 1 != 0
#     Ha right-tailed (diff > 0): mean 0 - mean 1 > 0
#   Wilcoxon signed-rank alternative hypotheses:
#     Ha left-tailed (P(x > y) < 0.5)
#     Ha two-tailed (P(x > y) != 0.5)
#     Ha right-tailed (P(x > y) > 0.5)

# %%
statistics.test_gaze_duration_outcomes(scenario_order_pairings[1])
# Out:
# visitDuration_infant:
#   mean diff = 5.870; stdev diff = 23.556
#   Paired t-test:
#     |diff| > 0: p = 0.449
#     diff < 0: p = 0.776
#     diff > 0: p = 0.224
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.424
#     P(x > y) < 0.5: p = 0.788
#     P(x > y) > 0.5: p = 0.212
# visitDuration_warmerInstrumentPanel:
#   mean diff = -4.431; stdev diff = 9.142
#   Paired t-test:
#    ~|diff| > 0: p = 0.156
#    *diff < 0: p = 0.078
#     diff > 0: p = 0.922
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.213
#    ~P(x > y) < 0.5: p = 0.107
#     P(x > y) > 0.5: p = 0.893
# visitDuration_fiO2Dial:
#   mean diff = -0.265; stdev diff = 3.084
#   Paired t-test:
#     |diff| > 0: p = 0.791
#     diff < 0: p = 0.396
#     diff > 0: p = 0.604
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.722
#     P(x > y) < 0.5: p = 0.361
#     P(x > y) > 0.5: p = 0.639
# visitDuration_spO2ReferenceTable:
#   mean diff = -0.462; stdev diff = 2.192
#   Paired t-test:
#     |diff| > 0: p = 0.520
#     diff < 0: p = 0.260
#     diff > 0: p = 0.740
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.657
#     P(x > y) < 0.5: p = 0.328
#     P(x > y) > 0.5: p = 0.672
# visitDuration_monitorFull:
#   mean diff = -2.137; stdev diff = 18.784
#   Paired t-test:
#     |diff| > 0: p = 0.726
#     diff < 0: p = 0.363
#     diff > 0: p = 0.637
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.534
#     P(x > y) < 0.5: p = 0.267
#     P(x > y) > 0.5: p = 0.733
# visitDuration_monitorBlank:
#   mean diff = -9.396; stdev diff = 9.752
#   Paired t-test:
#   **|diff| > 0: p = 0.012
#   **diff < 0: p = 0.006
#     diff > 0: p = 0.994
#   Wilcoxon signed-rank test:
#   **P(x > y) != 0.5: p = 0.010
#   **P(x > y) < 0.5: p = 0.005
#     P(x > y) > 0.5: p = 0.995
# visitDuration_monitorApgarTimer:
#   mean diff = 3.097; stdev diff = 6.583
#   Paired t-test:
#    ~|diff| > 0: p = 0.168
#     diff < 0: p = 0.916
#    *diff > 0: p = 0.084
#   Wilcoxon signed-rank test:
#    ~P(x > y) != 0.5: p = 0.155
#     P(x > y) < 0.5: p = 0.923
#    *P(x > y) > 0.5: p = 0.077
# visitDuration_monitorHeartRate:
#   mean diff = -0.871; stdev diff = 11.339
#   Paired t-test:
#     |diff| > 0: p = 0.813
#     diff < 0: p = 0.407
#     diff > 0: p = 0.593
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.790
#     P(x > y) < 0.5: p = 0.395
#     P(x > y) > 0.5: p = 0.605
# visitDuration_monitorFiO2:
#   mean diff = -2.554; stdev diff = 15.259
#   Paired t-test:
#     |diff| > 0: p = 0.608
#     diff < 0: p = 0.304
#     diff > 0: p = 0.696
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.929
#     P(x > y) < 0.5: p = 0.465
#     P(x > y) > 0.5: p = 0.535
# visitDuration_monitorGraph:
#   mean diff = 4.524; stdev diff = 15.986
#   Paired t-test:
#     |diff| > 0: p = 0.392
#     diff < 0: p = 0.804
#    ~diff > 0: p = 0.196
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.374
#     P(x > y) < 0.5: p = 0.813
#    ~P(x > y) > 0.5: p = 0.187
# visitDuration_monitorSpO2:
#   mean diff = 4.603; stdev diff = 16.845
#   Paired t-test:
#     |diff| > 0: p = 0.408
#     diff < 0: p = 0.796
#     diff > 0: p = 0.204
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.424
#     P(x > y) < 0.5: p = 0.788
#     P(x > y) > 0.5: p = 0.212
# visitDuration_combinedFiO2:
#   mean diff = -2.819; stdev diff = 15.941
#   Paired t-test:
#     |diff| > 0: p = 0.588
#     diff < 0: p = 0.294
#     diff > 0: p = 0.706
#   Wilcoxon signed-rank test:
#     P(x > y) != 0.5: p = 0.722
#     P(x > y) < 0.5: p = 0.361
#     P(x > y) > 0.5: p = 0.639
# visitDuration_combinedSpO2:
#   mean diff = 8.665; stdev diff = 16.831
#   Paired t-test:
#    ~|diff| > 0: p = 0.135
#     diff < 0: p = 0.933
#    *diff > 0: p = 0.067
#   Wilcoxon signed-rank test:
#    ~P(x > y) != 0.5: p = 0.131
#     P(x > y) < 0.5: p = 0.935
#    *P(x > y) > 0.5: p = 0.065

# %% [markdown]
# Observations:
#
# * Participants in scenario 2 look less at the blank part of the monitor, maybe more at the apgar timer, and maybe more at combined SpO2, and maybe less at the instrument panel compared to scenario 3.
# * These results are pretty weak but might suggest adaptation between scenarios 2 and 3.

# %% [markdown]
# #### Summary
#
# * There seems to be a learning effect between scenarios 1 and 4, but maybe not a strong effect between scenarios 2 and 3.
